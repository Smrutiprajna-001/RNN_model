# %% [markdown]
# <a href="https://colab.research.google.com/github/Smrutiprajna-001/RNN_model/blob/main/RNN_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras

# %%
# step 1
# import necessary libraries

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# %%
# step 2
# generating training data:sequencees like[1,2,3]->4
x=[]
y=[]
for i in range(1,10):
  x.append([i, i+1, i+2])
  y.append(i+3)

x=np.array(x).reshape((len(x),3,1))
y= np.array(y)

# %%
# step 3
# build the RNN model
model = Sequential()
model.add(SimpleRNN(10, activation='relu',input_shape=(3,1)))
model.add(Dense(1))
model.compile(optimizer ='adam' ,loss='mse')

# train model
model.fit(x,y,epochs=300 ,verbose=1)
# Out:
# Epoch 1/300
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 198.0421
# Epoch 2/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 196.8916
# Epoch 3/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 195.7475
# Epoch 4/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 194.6099
# Epoch 5/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 193.4788
# Epoch 6/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 192.3543
# Epoch 7/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 191.2364
# Epoch 8/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 190.1252
# Epoch 9/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 189.0207
# Epoch 10/300
# ...

# %%
# step 4
# test the model with a new sequence
test_input = np.array(([10,11,12])).reshape((1,3,1))
predicted = model.predict(test_input, verbose=0)

print(f"Input Sequence:[10,11,12]")
print(f"Predicted Next Number:{round(float(predicted[0][0]),2)}")
# Out:
# Input Sequence:[10,11,12]
# Predicted Next Number:11.98
